# %%
import pandas as pd

df_smart = pd.read_csv("../../src/data/smart_stat.csv", encoding="cp949")
#df_smart_seoul = df_smart[df_smart["시도명"] == "서울특별시"]
#result = df_smart_seoul.groupby("시군구명")["스마트가로등형태"].sum().reset_index()
print(df_smart)
# Out:
#       스마트가로등유형   시도명 시군구명    도로명           소재지도로명주소                  소재지지번주소  \
# 0            2  충청남도  공주시  고마나루길   충청남도 공주시 고마나루길75  충청남도 공주시 공주시 웅진동 344-23
# 1            2  충청남도  공주시  고마나루길   충청남도 공주시 고마나루길75  충청남도 공주시 공주시 웅진동 344-23
# 2            2  충청남도  공주시  고마나루길   충청남도 공주시 고마나루길75  충청남도 공주시 공주시 웅진동 344-23
# 3            2  충청남도  공주시  고마나루길   충청남도 공주시 고마나루길75  충청남도 공주시 공주시 웅진동 344-23
# 4            2  충청남도  공주시  관광단지길  충청남도 공주시 관광단지길 30   충청남도 공주시 공주시 웅진동 355-1
# ...        ...   ...  ...    ...                ...                      ...
# 10368        2  충청남도  공주시  월성산2길  충청남도 공주시 월성산2길 43     충청남도 공주시 공주시 옥룡동 425
# 10369        2  충청남도  공주시  월성산2길  충청남도 공주시 월성산2길 43     충청남도 공주시 공주시 옥룡동 425
# 10370        2  충청남도  공주시  월성산2길  충청남도 공주시 월성산2길 43     충청남도 공주시 공주시 옥룡동 425
# 10371        2  충청남도  공주시   우금티로  충청남도 공주시 우금티로 740   충청남도 공주시 공주시 옥룡동 185-1
# 10372        2  충청남도  공주시   우금티로  충청남도 공주시 우금티로 740   충청남도 공주시 공주시 옥룡동 185-1
#
#               위도          경도  스마트가로등형태 점등상태여부  ... 위급상황신고가능여부 앱서비스명 앱서비스제공내용  \
# 0      36.464146  127.107945         1      N  ...          N   NaN        무
# 1      36.464342  127.107693         1      N  ...          N   NaN        무
# 2      36.464582  127.107450         1      N  ...          N   NaN        무
# 3      36.464685  127.107352         1      N  ...          N   NaN        무
# 4      36.465227  127.106902         1      N  ...          N   NaN        무
# ...          ...         ...       ...    ...  ...        ...   ...      ...
# 10368  36.454250  127.134705         1      N  ...          N   NaN        무
# 10369  36.454252  127.135030         1      N  ...          N   NaN        무
# 10370  36.454239  127.135319         1      N  ...          N   NaN        무
# 10371  36.455956  127.133452         1      N  ...          N   NaN        무
# 10372  36.455860  127.133651         1      N  ...          N   NaN        무
#
#       기타서비스 설치연도 관리기관명      관리기관전화번호     데이터기준일자   제공기관코드     제공기관명
# 0       NaN  NaN  공주시청  041-840-8118  2022-11-21  4500000  충청남도 공주시
# 1       NaN  NaN  공주시청  041-840-8118  2022-11-21  4500000  충청남도 공주시
# 2       NaN  NaN  공주시청  041-840-8118  2022-11-21  4500000  충청남도 공주시
# 3       NaN  NaN  공주시청  041-840-8118  2022-11-21  4500000  충청남도 공주시
# 4       NaN  NaN  공주시청  041-840-8118  2022-11-21  4500000  충청남도 공주시
# ...     ...  ...   ...           ...         ...      ...       ...
# 10368   NaN  NaN  공주시청  041-840-8118  2022-11-21  4500000  충청남도 공주시
# 10369   NaN  NaN  공주시청  041-840-8118  2022-11-21  4500000  충청남도 공주시
# 10370   NaN  NaN  공주시청  041-840-8118  2022-11-21  4500000  충청남도 공주시
# 10371   NaN  NaN  공주시청  041-840-8118  2022-11-21  4500000  충청남도 공주시
# 10372   NaN  NaN  공주시청  041-840-8118  2022-11-21  4500000  충청남도 공주시
#
# [10373 rows x 27 columns]

# %%
import folium

# 서울특별시 데이터 필터링
seoul_df = df_smart[df_smart["시도명"] == "서울특별시"]

# 광진구만 필터링
gwangjin_df = seoul_df[seoul_df["시군구명"] == "광진구"]

# 지도 중심 좌표 설정 (광진구 중심 정도로 설정)
map_center = [gwangjin_df["위도"].mean(), gwangjin_df["경도"].mean()]
gwangjin_map = folium.Map(location=map_center, zoom_start=14)

# 가로등 위치마다 마커 추가
for _, row in gwangjin_df.iterrows():
    folium.CircleMarker(
        location=[row["위도"], row["경도"]],
        radius=4,
        color="blue",
        fill=True,
        fill_opacity=0.6,
        popup=row["소재지도로명주소"]
    ).add_to(gwangjin_map)

gwangjin_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_267bdc52bd46f98f0e3b6cc45f66d58a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_267bdc52bd46f98f0e3b6cc45f66d58a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_267bdc52bd46f98f0e3b6cc45f66d58a = L.map(
#                 &quot;map_267bdc52bd46f98f0e3b6cc45f66d58a&quot;,
#                 {
#                     center: [37.54781661311476, 127.08396582459015],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4b5320c7e0bca76d10ff8cd27bebfa51 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4b5320c7e0bca76d10ff8cd27bebfa51.addTo(map_267bdc52bd46f98f0e3b6cc45f66d58a);
#
#
#             var circle_marker_a7590155e88ebe09d5234fa12ff33ec5 = L.circleMarker(
#                 [37.5475574, 127.1077072],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_267bdc52bd46f98f0e3b6cc45f66d58a);
#
#
#         var popup_aafab43abae991022f91abc5bf7d27b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07f19d909e4f163ca4e87372668fb216 = $(`&lt;div id=&quot;html_07f19d909e4f163ca4e87372668fb216&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 광진구 아차산로76가길4&lt;/div&gt;`)[0];
#                 popup_aafab43abae991022f91abc5bf7d27b9.setContent(html_07f19d909e4f163ca4e87372668fb216);
#
#
#
#         circle_marker_a7590155e88ebe09d5234fa12ff33ec5.bindPopup(popup_aafab43abae991022f91abc5bf7d27b9)
#         ;
#
#
#
#
#             var circle_marker_53ac6e606a52208e679b898b6f385e69 = L.circleMarker(
#                 [37.5485266, 127.1097544],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_267bdc52bd46f98f0e3b6cc45f66d58a);
#
#
#         var popup_41d59eb390e920fcfac012647fe59fe2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c69c4b25456550cb9453c666b71225e = $(`&lt;div id=&quot;html_1c69c4b25456550cb9453c666b71225e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 광진구 아차산로78길157&lt;/div&gt;`)[0];
#                 popup_41d59eb390e920fcfac012647fe59fe2.setContent(html_1c69c4b25456550cb9453c666b71225e);
#
#
#
#         circle_marker_53ac6e606a52208e679b898b6f385e69.bindPopup(popup_41d59eb390e920fcfac012647fe59fe2)
#         ;
#
#
#
#
#             var circle_marker_cca36817d56b4841bb5b038069ceb16f = L.circleMarker(
#                 [37.5658919, 127.0855444],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_267bdc52bd46f98f0e3b6cc45f66d58a);
#
#
#         var popup_6f51ce1c70626a5feec202da12b56cba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09b9926e0689f284d791237c09b8f15a = $(`&lt;div id=&quot;html_09b9926e0689f284d791237c09b8f15a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 광진구 용마산로127&lt;/div&gt;`)[0];
#                 popup_6f51ce1c70626a5feec202da12b56cba.setContent(html_09b9926e0689f284d791237c09b8f15a);
#
#
#
#         circle_marker_cca36817d56b4841bb5b038069ceb16f.bindPopup(popup_6f51ce1c70626a5feec202da12b56cba)
#         ;
#
#
#
#
#             var circle_marker_5d2589627ad7eb84e94949ddc5f2e273 = L.circleMarker(
#                 [37.5455874, 127.1018481],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;:
